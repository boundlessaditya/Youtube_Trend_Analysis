# %% [raw]
# https://www.kaggle.com/datasets/nelgiriyewithana/global-youtube-statistics-2023

# %%
import pandas as pd
import numpy as np

# %%
def fill_null(df):
    for i in range(len(df)):
        str = df.columns[i]
        if df.iloc[:,i].dtypes != df.iloc[:,0].dtypes:
            df[str].fillna(df[str].mean(), inplace = True)
        else:
            df[str].fillna(df[str].value_counts().index[0], inplace = True)

# %%
Data = pd.read_csv("youtube_stats.csv",index_col = 0,encoding_errors = 'replace')
df = Data.copy()

# %%
df.head(5)
# Out:
#                         Youtuber  subscribers   video views          category  \
# rank
# 1                       T-Series    245000000  2.280000e+11             Music
# 2                 YouTube Movies    170000000  0.000000e+00  Film & Animation
# 3                        MrBeast    166000000  2.836884e+10     Entertainment
# 4     Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 5                      SET India    159000000  1.480000e+11             Shows
#
#                            Title  uploads        Country Abbreviation  \
# rank
# 1                       T-Series    20082          India           IN
# 2                  youtubemovies        1  United States           US
# 3                        MrBeast      741  United States           US
# 4     Cocomelon - Nursery Rhymes      966  United States           US
# 5                      SET India   116536          India           IN
#
# ...

# %%
print(df.columns)
print(df.shape)
# Out:
# Index(['Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')
# (995, 27)

# %%
df.iloc[:,0:18].head(5)
# Out:
#                         Youtuber  subscribers   video views          category  \
# rank
# 1                       T-Series    245000000  2.280000e+11             Music
# 2                 YouTube Movies    170000000  0.000000e+00  Film & Animation
# 3                        MrBeast    166000000  2.836884e+10     Entertainment
# 4     Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 5                      SET India    159000000  1.480000e+11             Shows
#
#                            Title  uploads        Country Abbreviation  \
# rank
# 1                       T-Series    20082          India           IN
# 2                  youtubemovies        1  United States           US
# 3                        MrBeast      741  United States           US
# 4     Cocomelon - Nursery Rhymes      966  United States           US
# 5                      SET India   116536          India           IN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 1 to 995
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Youtuber                                 995 non-null    object
#  1   subscribers                              995 non-null    int64
#  2   video views                              995 non-null    float64
#  3   category                                 949 non-null    object
#  4   Title                                    995 non-null    object
#  5   uploads                                  995 non-null    int64
#  6   Country                                  873 non-null    object
#  7   Abbreviation                             873 non-null    object
#  8   channel_type                             965 non-null    object
#  9   video_views_rank                         994 non-null    float64
# ...

# %%
df.iloc[:,0].dtypes
# Out:
# dtype('O')

# %%
fill_null(df)
# Out:
# C:\Users\Aditya Prakash\AppData\Local\Temp\ipykernel_10604\3691259559.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[str].fillna(df[str].value_counts().index[0], inplace = True)
# C:\Users\Aditya Prakash\AppData\Local\Temp\ipykernel_10604\3691259559.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df
# Out:
#                         Youtuber  subscribers   video views          category  \
# rank
# 1                       T-Series    245000000  2.280000e+11             Music
# 2                 YouTube Movies    170000000  0.000000e+00  Film & Animation
# 3                        MrBeast    166000000  2.836884e+10     Entertainment
# 4     Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 5                      SET India    159000000  1.480000e+11             Shows
# ...                          ...          ...           ...               ...
# 991                 Natan por A�     12300000  9.029610e+09            Sports
# 992     Free Fire India Official     12300000  1.674410e+09    People & Blogs
# 993                        Panda     12300000  2.214684e+09     Entertainment
# 994                  RobTopGames     12300000  3.741235e+08            Gaming
# 995                 Make Joke Of     12300000  2.129774e+09            Comedy
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 995 entries, 1 to 995
# Data columns (total 27 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Youtuber                                 995 non-null    object
#  1   subscribers                              995 non-null    int64
#  2   video views                              995 non-null    float64
#  3   category                                 995 non-null    object
#  4   Title                                    995 non-null    object
#  5   uploads                                  995 non-null    int64
#  6   Country                                  995 non-null    object
#  7   Abbreviation                             995 non-null    object
#  8   channel_type                             995 non-null    object
#  9   video_views_rank                         995 non-null    float64
# ...

# %%
#Datetime adjustment
df.created_date = df.created_date.astype('int')
df.created_year = df.created_year.astype('int')

# %%
df = df.sort_values(by = 'subscribers', ascending= False).reset_index(drop= True)
df
# Out:
#                        Youtuber  subscribers   video views          category  \
# 0                      T-Series    245000000  2.280000e+11             Music
# 1                YouTube Movies    170000000  0.000000e+00  Film & Animation
# 2                       MrBeast    166000000  2.836884e+10     Entertainment
# 3    Cocomelon - Nursery Rhymes    162000000  1.640000e+11         Education
# 4                     SET India    159000000  1.480000e+11             Shows
# ..                          ...          ...           ...               ...
# 990                Natan por A�     12300000  9.029610e+09            Sports
# 991    Free Fire India Official     12300000  1.674410e+09    People & Blogs
# 992                       Panda     12300000  2.214684e+09     Entertainment
# 993                 RobTopGames     12300000  3.741235e+08            Gaming
# 994                Make Joke Of     12300000  2.129774e+09            Comedy
#
# ...

# %%
df.category.value_counts()
# Out:
# category
# Entertainment            287
# Music                    202
# People & Blogs           132
# Gaming                    94
# Comedy                    69
# Film & Animation          46
# Education                 45
# Howto & Style             40
# News & Politics           26
# Science & Technology      17
# Shows                     13
# Sports                    11
# Pets & Animals             4
# Trailers                   2
# Nonprofits & Activism      2
# Movies                     2
# Autos & Vehicles           2
# Travel & Events            1
# Name: count, dtype: int64

# %%
np.unique(df.Country).size
# Out:
# 49

# %%
df.Country.value_counts()
# Out:
# Country
# United States           435
# India                   168
# Brazil                   62
# United Kingdom           43
# Mexico                   33
# Indonesia                28
# Spain                    22
# Thailand                 18
# South Korea              17
# Russia                   16
# Canada                   15
# Argentina                13
# Philippines              12
# Colombia                 11
# Australia                 9
# Saudi Arabia              9
# Ukraine                   8
# United Arab Emirates      7
# Pakistan                  6
# Germany                   6
# France                    5
# Japan                     5
# Turkey                    4
# Sweden                    4
# Vietnam                   3
# Jordan                    3
# Netherlands               3
# Singapore                 3
# Chile                     3
# Ecuador                   2
# Egypt                     2
# Iraq                      2
# Italy                     2
# ...

# %% [raw]
# Exploratory_data_analysis

# %%
pd.crosstab(index = df.category, columns = df.Country, margins = True)
# Out:
# Country                Afghanistan  Andorra  Argentina  Australia  Bangladesh  \
# category
# Autos & Vehicles                 0        0          0          0           0
# Comedy                           0        0          3          0           0
# Education                        0        0          1          1           0
# Entertainment                    0        0          3          0           0
# Film & Animation                 0        0          1          0           0
# Gaming                           0        0          1          3           0
# Howto & Style                    0        1          0          2           0
# Movies                           0        0          0          0           0
# Music                            1        0          4          2           0
# News & Politics                  0        0          0          0           1
# Nonprofits & Activism            0        0          0          0           0
# ...

# %%
numerical = df.select_dtypes(exclude = [object])
numerical.corr()
# Out:
#                                          subscribers  video views   uploads  \
# subscribers                                 1.000000     0.750958  0.077136
# video views                                 0.750958     1.000000  0.165928
# uploads                                     0.077136     0.165928  1.000000
# video_views_rank                            0.057195    -0.061796 -0.108984
# country_rank                                0.031190    -0.067059 -0.078051
# channel_type_rank                           0.026830    -0.049976 -0.098328
# video_views_for_the_last_30_days            0.270723     0.359644  0.101302
# lowest_monthly_earnings                     0.388941     0.552096  0.166922
# highest_monthly_earnings                    0.388579     0.551455  0.167283
# lowest_yearly_earnings                      0.389072     0.552776  0.167745
# highest_yearly_earnings                     0.388935     0.552091  0.166904
# ...

# %%
df.describe()
# Out:
#         subscribers   video views        uploads  video_views_rank  \
# count  9.950000e+02  9.950000e+02     995.000000      9.950000e+02
# mean   2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    1.752611e+07  1.411084e+10   34151.352254      1.362097e+06
# min    1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    1.450000e+07  4.288145e+09     194.500000      3.240000e+02
# 50%    1.770000e+07  7.760820e+09     729.000000      9.180000e+02
# 75%    2.460000e+07  1.355470e+10    2667.500000      3.617500e+03
# max    2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    995.000000         995.000000                      9.950000e+02
# mean     386.053470         745.719335                      1.756103e+08
# std     1158.113278        1911.838101                      4.044792e+08
# ...

# %% [raw]
# Trending_Topic_Analysis

# %%
df.video_views_for_the_last_30_days.mean()
# Out:
# 175610284.79446217

# %%
Trend = df[(df.video_views_for_the_last_30_days >= df.video_views_for_the_last_30_days.mean())]
Trend
# Out:
#                        Youtuber  subscribers   video views       category  \
# 0                      T-Series    245000000  2.280000e+11          Music
# 2                       MrBeast    166000000  2.836884e+10  Entertainment
# 3    Cocomelon - Nursery Rhymes    162000000  1.640000e+11      Education
# 4                     SET India    159000000  1.480000e+11          Shows
# 5                         Music    119000000  0.000000e+00  Entertainment
# ..                          ...          ...           ...            ...
# 977                    MoniLina     12400000  1.608681e+10         Comedy
# 984               Gustavo Par��     12400000  2.602614e+09         Comedy
# 988                DEV Ke Facts     12400000  1.971226e+09  Entertainment
# 989                    _vector_     12400000  7.597013e+09         Comedy
# 990                Natan por A�     12300000  9.029610e+09         Sports
#
#                           Title  uploads        Country Abbreviation  \
# ...

# %%
print(Trend.category.value_counts().median())
Trend.category.value_counts()
# Out:
# 9.0
# category
# Entertainment           95
# Music                   56
# People & Blogs          39
# Comedy                  24
# Education               14
# Film & Animation        13
# News & Politics         11
# Gaming                  11
# Shows                    7
# Howto & Style            4
# Sports                   3
# Science & Technology     2
# Autos & Vehicles         2
# Trailers                 1
# Movies                   1
# Pets & Animals           1
# Name: count, dtype: int64

# %%
x = Trend.category.value_counts() >= Trend.category.value_counts().median()
print(x)
x = x[x == False]
print(x)
x = x.index[:]
print(x)
# Out:
# category
# Entertainment            True
# Music                    True
# People & Blogs           True
# Comedy                   True
# Education                True
# Film & Animation         True
# News & Politics          True
# Gaming                   True
# Shows                   False
# Howto & Style           False
# Sports                  False
# Science & Technology    False
# Autos & Vehicles        False
# Trailers                False
# Movies                  False
# Pets & Animals          False
# Name: count, dtype: bool
# category
# Shows                   False
# Howto & Style           False
# Sports                  False
# Science & Technology    False
# Autos & Vehicles        False
# Trailers                False
# Movies                  False
# Pets & Animals          False
# Name: count, dtype: bool
# Index(['Shows', 'Howto & Style', 'Sports', 'Science & Technology',
#        'Autos & Vehicles', 'Trailers', 'Movies', 'Pets & Animals'],
# ...

# %%
Trend = Trend[Trend.category.isin(x) == False]
Trend
# Out:
#                        Youtuber  subscribers   video views        category  \
# 0                      T-Series    245000000  2.280000e+11           Music
# 2                       MrBeast    166000000  2.836884e+10   Entertainment
# 3    Cocomelon - Nursery Rhymes    162000000  1.640000e+11       Education
# 5                         Music    119000000  0.000000e+00   Entertainment
# 6           ��� Kids Diana Show    112000000  9.324704e+10  People & Blogs
# ..                          ...          ...           ...             ...
# 975                        TKOR     12400000  3.392023e+09       Education
# 977                    MoniLina     12400000  1.608681e+10          Comedy
# 984               Gustavo Par��     12400000  2.602614e+09          Comedy
# 988                DEV Ke Facts     12400000  1.971226e+09   Entertainment
# 989                    _vector_     12400000  7.597013e+09          Comedy
#
# ...

# %%
Trend.category.value_counts()
# Out:
# category
# Entertainment       95
# Music               56
# People & Blogs      39
# Comedy              24
# Education           14
# Film & Animation    13
# News & Politics     11
# Gaming              11
# Name: count, dtype: int64

# %%
Top_10_Trending_countries = Trend.Country.value_counts().index[:11]
Top_10_Trending_countries
# Out:
# Index(['United States', 'India', 'Brazil', 'Argentina', 'United Kingdom',
#        'Russia', 'Indonesia', 'Colombia', 'South Korea', 'Canada', 'Mexico'],
#       dtype='object', name='Country')
